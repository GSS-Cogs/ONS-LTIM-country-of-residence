# %% [markdown]
# Long-term international migration 2.02, last or next resident, UK and England and Wales

# %%
from gssutils import *
scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/longterminternationalmigrationcountryoflastornextresidencetable202')
scraper
# Out:
# ## Long-term international migration 2.02, country of last or next residence, UK and England and Wales
#
# Nation of origin or destination of migrants. Estimates of Long-Term International Migration, annual table.
#
# ### Distributions
#
# 1. Long-term international migration 2.02, country of last or next residence, UK and England and Wales ([MS Excel Spreadsheet](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/longterminternationalmigrationcountryoflastornextresidencetable202/current/2.02ltimcountryoflastornextresidence2004to2017.xls))

# %%
tab = next(t for t in scraper.distribution().as_databaker() if t.name == 'Table 2.02')

# %%
cell = tab.filter('Year')
cell.assert_one()
Residence = cell.fill(RIGHT).is_not_blank().is_not_whitespace()  | \
            cell.shift(0,1).fill(RIGHT).is_not_blank().is_not_whitespace() | \
            cell.shift(0,2).expand(RIGHT).is_not_blank().is_not_whitespace().is_not_bold() \
            .filter(lambda x: type(x.value) != 'All' not in x.value)

# %%
observations = cell.shift(RIGHT).fill(DOWN).filter('Estimate').expand(RIGHT).filter('Estimate') \
                .fill(DOWN).is_not_blank().is_not_whitespace() 
Str =  tab.filter(contains_string('Significant Change?')).fill(RIGHT).is_not_number()
observations = observations - (tab.excel_ref('A1').expand(DOWN).expand(RIGHT).filter(contains_string('Significant Change')))
original_estimates = tab.filter(contains_string('Original Estimates')).fill(DOWN).is_number()
observations = observations - original_estimates - Str

# %%
CI = observations.shift(RIGHT)

# %%
Year = cell.fill(DOWN) 
Year = Year.filter(lambda x: type(x.value) != str or 'Significant Change?' not in x.value)

# %%
Geography = cell.fill(DOWN).one_of(['United Kingdom', 'England and Wales'])
Flow = cell.fill(DOWN).one_of(['Inflow', 'Outflow', 'Balance'])

# %%
csObs = ConversionSegment(observations, [
    HDim(Year,'Year', DIRECTLY, LEFT),
    HDim(Geography,'Geography', CLOSEST, ABOVE),
    HDim(Residence, 'Country of Residence', DIRECTLY, ABOVE),
    HDim(Flow, 'Flow', CLOSEST, ABOVE),
    HDimConst('Measure Type', 'Count'),
    HDimConst('Unit','People (thousands)'),
    HDim(CI,'CI',DIRECTLY,RIGHT),
    HDimConst('Revision', '2011 Census Revision')
])
savepreviewhtml(csObs)
tidy_revised = csObs.topandas()
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# td.xc17 { background-color: LightGray }
# td.xc18 { background-color: PaleTurquoise }
# td.xc19 { background-color: Tan }
# td.xc20 { background-color: SkyBlue }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { background-color: red; border: thin blue dotted }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0">OBS</td><td class="xc1">Year</td><td class="xc2">Geography</td><td class="xc3">Country of Residence</td><td class="xc4">Flow</td><td class="xc7">CI</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 2.02</caption>
# <tr><td class="" title="0 0"></td><td class="" title="1 0"></td><td class="" title="2 0"></td><td class="" title="3 0"></td><td class="" title="4 0"></td><td class="" title="5 0"></td><td class="" title="6 0"></td><td class="" title="7 0"></td><td class="" title="8 0"></td><td class="" title="9 0"></td><td class="" title="10 0"></td><td class="" title="11 0"></td><td class="" title="12 0"></td><td class="" title="13 0"></td><td class="" title="14 0"></td><td class="" title="15 0"></td><td class="" title="16 0"></td><td class="" title="17 0"></td><td class="" title="18 0"></td
# <tr><td class="" title="0 3"></td><td class="" title="1 3"></td><td class="" title="2 3"></td><td class="" title="3 3"></td><td class="" title="4 3"></td><td class="" title="5 3"></td><td class="" title="6 3"></td><td class="" title="7 3"></td><td class="" title="8 3"></td><td class="" title="9 3"></td><td class="" title="10 3"></td><td class="" title="11 3"></td><td class="" title="12 3"></td><td class="" title="13 3"></td><td class="" title="14 3"></td><td class="" title="15 3"></td><td class="" title="16 3"></td><td class="" title="17 3"></td><td class="" title="18 3"></td><td class="" title="19 3"></td><td class="" title="20 3"></td><td class="" title="21 3"></td><td class="" title="22 3"></td><td class="" title="23 3"></td><td class="" title="24 3"></td><td class="" title="25 3"></td><td class="" title="26 3"></td><td class="" title="27 3"></td><td class="" title="28 3"></td><td class="" title="29 3"></td><td class="" title="30 3"></td><td class="" title="31 3"></td><td class="" title="32 3"></td><td class="" title="33 3"></td><td class="" title="34 3"></td><td class="" title="35 3"></td><td class="" title="36 3"></td><td class="" title="37 3"></td><td class="" title="38 3"></td><td class="" title="39 3"></td><td class="" title="40 3"></td><td class="" title="41 3"></td><td class="" title="42 3"></td><td class="" title="43 3"></td></tr>
# <tr><td class="" title="0 4"></td><td class="" title="1 4"></td><td class="" title="2 4"></td><td class="" title="3 4"></td><td class="" title="4 4"></td><td class="" title="5 4"></td><td class="" title="6 4"></td><td class="" title="7 4"></td><td class="" title="8 4"></td><td class="" title="9 4"></td><td class="" title="10 4"></td><td class="" title="11 4"></td><td class="" title="12 4"></td><td class="" title="13 4"></td><td class="" title="14 4"></td><td class="" title="15 4"></td><td class="" title="16 4"></td><td class="" title="17 4"></td><td class="" title="18 4"></td><td class="" title="19 4"></td><td class="" title="20 4"></td><td class="" title="21 4"></td><td class="" title="22 4"></td><td class="" title="23 4"></td><td class="" title="24 4"></td><td class="" title="25 4"></td><td class="" title="26 4"></td><td class="" title="27 4"></td><td class="" title="28 4"></td><t

# %%
csRevs = ConversionSegment(original_estimates, [
    HDim(Year, 'Year', DIRECTLY, LEFT),
    HDim(Geography,'Geography', CLOSEST, ABOVE),
    HDim(Residence, 'Country of Residence', DIRECTLY, ABOVE),
    HDim(Flow, 'Flow', CLOSEST, ABOVE),
    HDimConst('Measure Type', 'Count'),
    HDimConst('Unit','People (thousands)'),
    HDim(original_estimates.shift(RIGHT), 'CI', DIRECTLY, RIGHT),
    HDimConst('Revision', 'Original Estimate')
])
orig_estimates = csRevs.topandas()

# %%
tidy = pd.concat([tidy_revised, orig_estimates], axis=0, join='outer', ignore_index=True, sort=False)

# %%
import numpy as np
tidy['OBS'].replace('', np.nan, inplace=True)
tidy.dropna(subset=['OBS'], inplace=True)
if 'DATAMARKER' in tidy.columns:
    tidy.drop(columns=['DATAMARKER'], inplace=True)
tidy.rename(columns={'OBS': 'Value'}, inplace=True)
tidy['Value'] = tidy['Value'].astype(int)
tidy['CI'] = tidy['CI'].map(lambda x:'' if x == ':' else int(x[:-2]) if x.endswith('.0') else 'ERR')

# %%
for col in tidy.columns:
    if col not in ['Value', 'Year', 'CI']:
        tidy[col] = tidy[col].astype('category')
        display(col)
        display(tidy[col].cat.categories)
# Out:
# 'Geography'
# Index(['England and Wales', 'United Kingdom'], dtype='object')
# 'Country of Residence'
# Index(['All countries', 'All3', 'Asia', 'Central and South America',
#        'East Asia', 'European Union EU15', 'European Union EU2',
#        'European Union EU8', 'European Union Other', 'European Union2',
#        'Middle East and Central Asia', 'North Africa', 'North America',
#        'Oceania', 'Other Europe3', 'Rest of the World', 'South Asia',
#        'South East Asia', 'Sub-Saharan Africa'],
#       dtype='object')
# 'Flow'
# Index(['Balance', 'Inflow', 'Outflow'], dtype='object')
# 'Measure Type'
# Index(['Count'], dtype='object')
# 'Unit'
# Index(['People (thousands)'], dtype='object')
# 'Revision'
# Index(['2011 Census Revision', 'Original Estimate'], dtype='object')

# %%
tidy['Geography'] = tidy['Geography'].cat.rename_categories({
    'United Kingdom': 'K02000001',
    'England and Wales': 'K04000001'
})
tidy['Country of Residence'] = tidy['Country of Residence'].cat.rename_categories({
    'All3' : 'non-eu',
    'Central and South America' : 'central-and-south-america', 
    'East Asia' : 'east-asia', 
    'European Union EU15' : 'eu15',
    'European Union EU2' : 'eu2', 
    'European Union EU8' : 'eu8', 
    'European Union Other' : 'eu-other',
    'European Union2' : 'eu' , 
    'Middle East and Central Asia' : 'middle-east-and-central-asia' ,
    'North Africa' : 'north-africa', 
    'North America' : 'north-america', 
    'Oceania' : 'oceania',
    'Other Europe3' : 'europe-exc-eu', 
    'Rest of the World' : 'rest-of-world', 
    'South Asia' : 'south-asia', 
    'South East Asia' :'south-east-asia',
    'Sub-Saharan Africa' : 'sub-saharan-africa',
    'All countries' : 'all',
    'Asia'  : 'asia'
            
})
tidy['Flow'] = tidy['Flow'].cat.rename_categories({
    'Balance': 'balance', 
    'Inflow': 'inflow',
    'Outflow': 'outflow'
})

tidy = tidy[['Geography', 'Year', 'Country of Residence', 'Flow',
              'Measure Type','Value', 'CI','Unit', 'Revision']]

# %%
tidy['Year'] = tidy['Year'].apply(lambda x: pd.to_numeric(x, downcast='integer'))

# %%
tidy['Year'] = tidy['Year'].astype(int)

# %%
tidy
# Out:
#       Geography  Year          Country of Residence     Flow Measure Type  \
# 0     K02000001  2004                           all   inflow        Count
# 1     K02000001  2004                            eu   inflow        Count
# 2     K02000001  2004                          eu15   inflow        Count
# 3     K02000001  2004                           eu8   inflow        Count
# 5     K02000001  2004                      eu-other   inflow        Count
# 6     K02000001  2004                        non-eu   inflow        Count
# 7     K02000001  2004                 europe-exc-eu   inflow        Count
# 8     K02000001  2004                          asia   inflow        Count
# 9     K02000001  2004  middle-east-and-central-asia   inflow        Count
# 10    K02000001  2004                     east-asia   inflow        Count
# 11    K02000001  2004                    south-asia   inflow        Count
# 12    K02000001  2004               south-east-asia   inflow        Count
# 13    K02000001  2004                 rest-of-world   inflow        Count
# 14    K02000001  2004            sub-saharan-africa   inflow        Count
# 15    K02000001  2004                  north-africa   inflow        Count
# 16    K02000001  2004                 north-america   inflow        Count
# 17    K02000001  2004     central-and-south-america   inflow        Count
# 18    K02000001  2004                       oceania   inflow        Count
# 19    K02000001  2005                           all   inflow        Count
# 20    K02000001  2005                            eu   inflow        Count
# 21    K02000001  2005                          eu15   inflow        Count
# 22    K02000001  2005                           eu8   inflow        Count
# 24    K02000001  2005                      eu-other   inflow        Count
# 25    K02000001  2005                        non-eu   inflow        Count
# 26    K02000001  2005                 europe-exc-eu   inflow        Count
# 27    K02000001  2005                          asia   inflow        Count
# 28    K02000001  2005  middle-east-and-central-asia   inflow        Count
# 29    K02000001  2005                     east-asia   inflow        Count
# 30    K02000001  2005                    south-asia   inflow        Count
# 31    K02000001  2005               south-east-asia   inflow        Count
# ...         ...   ...                           ...      ...          ...
# 1574  K04000001  2016                 north-america  balance        Count
# 1575  K04000001  2016     central-and-south-america  balance        Count
# 1576  K04000001  2016                       oceania  balance        Count
# 1577  K04000001  2017                           all  balance        Count
# 1578  K04000001  2017                            eu  balance        Count
# 1579  K04000001  2017                          eu15  balance        Count
# 1580  K04000001  2017                           eu8  balance        Count
# 1581  K04000001  2017                           eu2  balance        Count
# 1582  K04000001  2017                      eu-other  balance        Count
# 1583  K04000001  2017                        non-eu  balance        Count
# 1584  K04000001  2017                 europe-exc-eu  balance        Count
# 1585  K04000001  2017                          asia  balance        Count
# 1586  K04000001  2017  middle-east-and-central-asia  balance        Count
# 1587  K04000001  2017                     east-asia  balance        Count
# 1588  K04000001  2017                    south-asia  balance        Count
# 1589  K04000001  2017               south-east-asia  balance        Count
# 1590  K04000001  2017                 rest-of-world  balance        Count
# 1591  K04000001  2017            sub-saharan-africa  balance        Count
# 1592  K04000001  2017                  north-africa  balance        Count
# 1593  K04000001  2017                 north-america  balance        Count
# 1594  K04000001  2017     central-and-south-america  balance        Count
# 1595  K04000001  2017                       oceania  balance        Count
# 1596  K02000001  2004                           all  balance        Count
# 1597  K02000001  2005                           all  balance        Count
# 1598  K02000001  2006                           all  balance        Count
# 1599  K02000001  2007                           all  balance        Count
# 1600  K02000001  2008                           all  balance        Count
# 1601  K02000001  2009                           all  balance        Count
# 1602  K02000001  2010                           all  balance        Count
# 1603  K02000001  2011                           all  balance        Count
#
#       Value  CI                Unit              Revision
# 0       589  40  People (thousands)  2011 Census Revision
# 1       151  24  People (thousands)  2011 Census Revision
# 2        98  18  People (thousands)  2011 Census Revision
# 3        51  16  People (thousands)  2011 Census Revision
# 5         2   2  People (thousands)  2011 Census Revision
# 6       438  32  People (thousands)  2011 Census Revision
# 7        19   6  People (thousands)  2011 Census Revision
