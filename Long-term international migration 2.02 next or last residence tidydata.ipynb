# %% [markdown]
# Long-term international migration 2.02, last or next resident, UK and England and Wales

# %%
from databaker.framework import *
import pandas as pd

# %%
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

# %run scrape_ons.ipynb

metadata = scrape('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/longterminternationalmigrationcountryoflastornextresidencetable202')
metadata
# Out:
# {'about': 'Nation of origin or destination of migrants. Estimates of Long-Term International Migration, annual table.',
#  'fileURL': 'https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/longterminternationalmigrationcountryoflastornextresidencetable202/current/2.02ltimcountryoflastornextresidence2004to2016.xls',
#  'mailto': 'mailto:migstatsunit@ons.gsi.gov.uk',
#  'releaseDate': datetime.date(2017, 11, 30),
#  'title': 'Long-term international migration 2.02, country of last or next residence, UK and England and Wales'}

# %%
inputFile = sourceFolder / 'data.xls'
response = session.get(metadata['fileURL'])
with open(inputFile, 'wb') as f:
  f.write(response.content)
tab = loadxlstabs(inputFile, sheetids='Table 2.02')[0]
# Out:
# Loading in\data.xls which has size 253440 bytes
# Table names: ['Table 2.02']

# %%
# tab = pd.read_excel(inputFile, header = None, sheet_name = 1)
# tab

# %%
observations = tab.excel_ref('B21').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B116').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<Z57 65.0>, <N97 2.0>, <Z62 32.0>, <E61 68.0>, <AM81 20.0>, <AB45 -18.0>, <V92 -15.0>, <AO108 -32.0>, <J58 17.0>, <AB91 -10.0>, <Y39 8.0>, <AC72 8.0>, <AK100 'No'>, <G62 46.0>, <Y74 9.0>, <AR54 49.0>, <T76 205.0>, <W88 3.0>, <AP113 8.0>, <AI53 6.0>, <N76 4.0>, <F87 20.0>, <H53 27.0>, <V82 39.0>, <AC63 7.0>, <P28 361.0>, <AB40 -15.0>, <N38 2.0>, <AP94 7.0>, <L110 4.0>, <T41 -74.0>, <X106 22.0>, <I88 -17.0>, <AM94 -6.0>, <Z42 -24.0>, <U73 19.0>, <X81 53.0>, <G27 111.0>, <P99 -160.0>, <H78 14.0>, <J89 11.0>, <B73 549.0>, <K49 -12.0>, <Z91 -16.0>, <AN47 2.0>, <W108 5.0>, <AJ38 1.0>, <J106 25.0>, <T26 217.0>, <Y109 7.0>, <AL40 5.0>, <AO110 -24.0>, <F88 22.0>, <AF108 15.0>, <N80 3.0>, <AL74 6.0>, <AE66 'No'>, <AH22 10.0>, <Z21 91.0>, <Q78 18.0>, <AI82 6.0>, <P105 127.0>, <AF99 10.0>, <K107 3.0>, <AC29 6.0>, <AP55 15.0>, <J95 5.0>, <K77 8.0>, <Y88 9.0>, <E47 -127.0>, <AK108 1.0>, <F65 32.0>, <Q43 11.0>, <E41 -202.0>, <AH83 6.0>, <Y37 8.0>, <H46 13.0>, <AC41 2.0>, <M77 7.0>, <Y62 11.0>, <AI89 -2.0>, <F90 21.0>, <AC38 3.0>, <E115 101.0>, <J48 7.0>, <U57 20.0>, <AC37 5.0>, <AE99 -87.0>, <X62 40.0>, <AO64 -2.0>, <K109 7.0>, <B30 526.0>, <AB21 33.0>, <AP62 9.0>, <AJ27 5.0>, <G45 -79.0>, <C72 36.0>, <J73 19.0>, <AE80 105.0>, <Z97 -20.0>, <E109 56.0>, <H65 25.0>, <L94 3.0>, <W76 5.0>, <Q61 22.0>, <I100 'Up'>, <Y77 7.0>, <AI99 -3.0>, <AL81 9.0>, <Q89 20.0>, <Z34 'No'>, <AA93 3.0>, <AH80 4.0>, <X60 35.0>, <I63 47.0>, <J43 8.0>, <B22 567.0>, <Y30 11.0>, <K39 'z'>, <Z33 58.0>, <AC104 9.0>, <AO113 -6.0>, <AN91 4.0>, <H109 21.0>, <AC31 6.0>, <N41 2.0>, <Y92 4.0>, <F115 31.0>, <F92 17.0>, <B25 590.0>, <P78 335.0>, <AE30 111.0>, <P61 109.0>, <H43 14.0>, <AA64 9.0>, <AI81 8.0>, <G26 115.0>, <M98 -4.0>, <B87 -311.0>, <G46 -79.0>, <B77 532.0>, <AK91 -29.0>, <W28 6.0>, <W99 4.0>, <AO32 37.0>, <AH73 8.0>, <AC26 6.0>, <X34 'No'>, <M64 0.0>, <P27 382.0>, <AJ48 1.0>, <E40 -131.0>, <F31 27.0>, <Y58 8.0>, <H83 20.0>, <S60 8.0>, <F98 16.0>, <I34 'Down'>, <AM106 2.0>, <AP56 11.0>, <N42 2.0>, <AI94 -2.0>, <AB103 17.0>, <I58 18.0>, <AC40 4.0>, <W63 8.0>, <P42 -224.0>, <AF82 13.0>, <AH95 3.0>, <C105 49.0>, <K37 'z'>, <AK54 -4.0>, <AP47 6.0>, <AG74 45.0>, <AL31 9.0>, <T99 -67.0>, <L103 'z'>, <AA61 9.0>, <N110 5.0>, <AM60 1.0>, <G76 96.0>, <AG66 'No'>, <AG75 53.0>, <AK115 -6.0>, <AI83 7.0>, <E65 110.0>, <W79 5.0>, <X44 -27.0>, <AL109 7.0>, <L59 3.0>, <AA94 4.0>, <P90 -188.0>, <AK53 -2.0>, <AB81 25.0>, <H106 26.0>, <AO49 -38.0>, <AP63 8.0>, <X23 46.0>, <C21 40.0>, <AE87 -126.0>, <P84 'No'>, <AJ61 4.0>, <H114 21.0>, <AC25 8.0>, <Z92 -22.0>, <G112 41.0>, <V49 -17.0>, <F32 25.0>, <C79 26.0>, <P55 132.0>, <S111 6.0>, <E62 106.0>, <AL75 7.0>, <AI96 -3.0>, <X78 55.0>, <AL46 5.0>, <AN64 7.0>, <L97 2.0>, <B27 591.0>, <AH99 2.0>, <F63 33.0>, <S81 5.0>, <B108 179.0>, <U94 7.0>, <AI50 'No'>, <F28 20.0>, <P112 105.0>, <AL42 6.0>, <H98 13.0>, <AE34 'No'>, <X25 40.0>, <AE81 131.0>, <L71 'z'>, <T40 -65.0>, <N28 5.0>, <AI49 -4.0>, <AK109 -4.0>, <E30 220.0>, <T65 103.0>, <AF92 8.0>, <AI60 2.0>, <B46 -317.0>, <V80 26.0>, <F61 26.0>, <U111 15.0>, <B60 205.0>, <I108 14.0>, <AM111 2.0>, <N45 2.0>, <S30 5.0>, <AB100 'No'>, <I78 68.0>, <L37 'z'>, <B40 -341.0>, <AK77 27.0>, <AO44 -62.0>, <M55 4.0>, <M75 5.0>, <Z100 'No'>, <T54 127.0>, <AP39 12.0>, <AE75 138.0>, <X64 41.0>, <AL114 8.0>, <S64 7.0>, <I62 44.0>, <G63 68.0>, <AJ39 1.0>, <AL48 5.0>, <N27 5.0>, <Y87 7.0>, <L32 14.0>, <R74 15.0>, <C109 35.0>, <AN54 6.0>, <M89 -3.0>, <N72 3.0>, <AJ23 3.0>, <AB92 -12.0>, <M23 7.0>, <C26 30.0>, <C43 20.0>, <AI26 4.0>, <AJ95 0.0>, <L114 14.0>, <AI74 6.0>, <Z66 'No'>, <R83 18.0>, <R46 -13.0>, <Q83 21.0>, <Y46 4.0>, <M99 -3.0>, <AE91 -124.0>, <I53 45.0>, <C90 25.0>, <P59 179.0>, <W23 5.0>, <J80 12.0>, <AJ92 1.0>, <S63 8.0>, <U42 6.0>, <AH21 13.0>, <N47 2.0>, <M76 5.0>, <M100 'No'>, <J64 13.0>, <T108 133.0>, <S58 7.0>, <J27 15.0>, <J45 6.0>, <Q32 21.0>, <AQ57 163.0>, <H104 27.0>, <Q37 19.0>, <R24 18.0>, <X39 -26.0>, <AJ79 4.0>, <G77 95.0>, <AN32 6.0>, <F27 24.0>, <AE49 -97.0>, <F72 26.0>, <B49 -340.0>,  ...

# %%
Citizenship1 = tab.excel_ref('B12').expand(RIGHT).is_not_blank()
Citizenship1
# Out:
# {<AQ12 'All countries'>, <P12 'Non-European Union3'>, <B12 'All countries'>, <E12 'European Union2'>}

# %%
Citizenship2 = tab.excel_ref('E13').expand(RIGHT).is_not_blank()
Citizenship2
# Out:
# {<R13 'Other Europe3'>, <AE13 'Rest of the World'>, <I13 'European Union EU8'>, <T13 'Asia'>, <E13 'European Union2'>, <P13 'All3'>, <M13 'European Union Other'>, <K13 'European Union EU2'>, <G13 'European Union EU15'>}

# %%
Citizenship3 = tab.excel_ref('T14').expand(RIGHT).is_not_blank()
Citizenship3
# Out:
# {<V14 'Middle East and Central Asia'>, <AE14 'All'>, <AM14 'Central and South America'>, <AB14 'South East Asia'>, <T14 'All'>, <AQ14 'Original Estimates1'>, <Z14 'South Asia'>, <AI14 'North Africa'>, <AO14 'Oceania'>, <X14 'East Asia'>, <AK14 'North America'>, <AG14 'Sub-Saharan Africa'>}

# %%
Geography = tab.excel_ref('A').expand(DOWN).by_index([17,67])
Geography
# Out:
# {<A17 'United Kingdom'>, <A67 'England and Wales'>}

# %%
Flow = tab.excel_ref('A').expand(DOWN).by_index([19,35,51,69,85,101])
Flow
# Out:
# {<A19 'Inflow'>, <A69 'Inflow'>, <A51 'Balance'>, <A85 'Outflow'>, <A101 'Balance'>, <A35 'Outflow'>}

# %%
Year = tab.excel_ref('A12').expand(DOWN) - Geography - Flow - tab.excel_ref('A116').expand(DOWN)  
Year
# Out:
# {<A32 '2015'>, <A29 2012.0>, <A63 2014.0>, <A92 2009.0>, <A58 2009.0>, <A37 2004.0>, <A79 2012.0>, <A78 2011.0>, <A77 2010.0>, <A96 2013.0>, <A82 '2015'>, <A39 2006.0>, <A28 2011.0>, <A34 'Significant Change?'>, <A59 2010.0>, <A38 2005.0>, <A14 ''>, <A73 2006.0>, <A13 ''>, <A40 2007.0>, <A62 2013.0>, <A22 2005.0>, <A36 ''>, <A48 '2015'>, <A24 2007.0>, <A83 '2016'>, <A81 2014.0>, <A103 2004.0>, <A76 2009.0>, <A20 ''>, <A84 'Significant Change?'>, <A42 2009.0>, <A21 2004.0>, <A31 2014.0>, <A33 '2016'>, <A100 'Significant Change?'>, <A104 2005.0>, <A80 2013.0>, <A98 '2015'>, <A23 2006.0>, <A12 'Year'>, <A113 2014.0>, <A110 2011.0>, <A107 2008.0>, <A102 ''>, <A88 2005.0>, <A50 'Significant Change?'>, <A43 2010.0>, <A65 '2016'>, <A60 2011.0>, <A57 2008.0>, <A91 2008.0>, <A86 ''>, <A66 'Significant Change?'>, <A27 2010.0>, <A105 2006.0>, <A46 2013.0>, <A106 2007.0>, <A64 '2015'>, <A61 2012.0>, <A99 '2016'>, <A87 2004.0>, <A97 2014.0>, <A90 2007.0>, <A26 2009.0>, <A47 2014.0>, <A49 '2016'>, <A111 2012.0>, <A108 2009.0>, <A16 ''>, <A109 2010.0>, <A53 2004.0>, <A15 ''>, <A114 '2015'>, <A95 2012.0>, <A94 2011.0>, <A93 2010.0>, <A72 2005.0>, <A112 2013.0>, <A18 ''>, <A55 2006.0>, <A44 2011.0>, <A41 2008.0>, <A75 2008.0>, <A70 ''>, <A54 2005.0>, <A89 2006.0>, <A25 2008.0>, <A30 2013.0>, <A68 ''>, <A56 2007.0>, <A45 2012.0>, <A115 '2016'>, <A71 2004.0>, <A52 ''>, <A74 2007.0>}

# %%
Tag = tab.excel_ref('B15').expand(RIGHT).is_not_blank()
Tag
# Out:
# {<AO15 'Estimate'>, <AB15 'Estimate'>, <Q15 '+/-CI'>, <AP15 '+/-CI'>, <M15 'Estimate'>, <AI15 'Estimate'>, <F15 '+/-CI'>, <AJ15 '+/-CI'>, <U15 '+/-CI'>, <G15 'Estimate'>, <Y15 '+/-CI'>, <V15 'Estimate'>, <I15 'Estimate'>, <AE15 'Estimate'>, <R15 'Estimate'>, <J15 '+/-CI'>, <S15 '+/-CI'>, <P15 'Estimate'>, <AC15 '+/-CI'>, <AN15 '+/-CI'>, <W15 '+/-CI'>, <AF15 '+/-CI'>, <X15 'Estimate'>, <AQ15 'Estimate'>, <N15 '+/-CI'>, <AR15 '+/-CI'>, <B15 'Estimate'>, <AK15 'Estimate'>, <H15 '+/-CI'>, <C15 '+/-CI'>, <Z15 'Estimate'>, <AA15 '+/-CI'>, <K15 'Estimate'>, <AG15 'Estimate'>, <T15 'Estimate'>, <L15 '+/-CI'>, <AH15 '+/-CI'>, <AL15 '+/-CI'>, <E15 'Estimate'>, <AM15 'Estimate'>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(Geography,'Geography',CLOSEST,ABOVE),
            HDim(Citizenship1,'Citizenship1',CLOSEST,LEFT),
            HDim(Citizenship2,'Region',CLOSEST,LEFT),
            HDim(Citizenship3,'Territory',CLOSEST,LEFT),
            HDim(Flow,'Flow',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People(thousands)'),
            HDim(Tag, 'Tag',DIRECTLY,ABOVE)
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# td.xc17 { background-color: LightGray }
# td.xc18 { background-color: PaleTurquoise }
# td.xc19 { background-color: Tan }
# td.xc20 { background-color: SkyBlue }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { background-color: red; border: thin blue dotted }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0">OBS</td><td class="xc1">Year</td><td class="xc2">Geography</td><td class="xc3">Citizenship1</td><td class="xc4">Region</td><td class="xc5">Territory</td><td class="xc6">Flow</td><td class="xc9">Tag</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 2.02</caption>
# <tr><td class="" title="0 0"></td><td class="" title="1 0"></td><td class="" title="2 0"></td><td class="" title="3 0"></td><td class="" title="4 0"></td><td class="" title="5 0"></td><td class="" title="6 0"></td><td class="" title="7 0"></td><td class="" title="8 0"></td><td class="" title="9 0"></td><td class="" title="10 0"></td><td class="" title="11 0"></td><td class="" title="12 0"></td><td class="" title="13 0"></td><td class="" title="14 0"></td><td class="" title="15 0"></td><td class="" title="16 0"></td><td class="" title="17 0"></td><td class="" title="18 0"></td><td class="" title="19 0"></td><td class="" title="20 0"></td><td class="" title="21 0"></td><td class="" title="22 0"></td><td class="" title="23 0"></td><td class="" title="24 0"></td><td class="" title="25 0"></td><td class="" title="26 0"></td><td class="" title="27 0"></td><td class="" title="28 0"></td><td class="" title="29 0"></td><td class="" title="30 0"></td><td class="" title="31 0"></td><td class="" title="32 0"></td><td class="" title="33 0"></td><td class="" title="34 0"></td><td class="" title="35 0"></td><td class="" title="36 0"></td><td class="" title="37 0"></td><td class="" title="38 0"></td><td class="" title="39 0"></td><td class="" title="40 0"></td><td class="" title="41 0"></td><td class="" title="42 0"></td><td class="" title="43 0"></td></tr>
# <tr><td class="" title="0 1"></td><td class="" title="1 1"></td><td class="" title="2 1"></td><td class="" title="3 1"></td><td class="" title="4 1"></td><td class="" title="5 1"></td><td class="" title="6 1"></td><td class="" title="7 1"></td><td class="" title="8 1"></td><td class="" title="9 1"></td><td class="" title="10 1"></td><td class="" title="11 1"></td><td class="" title="12 1"></td><td class="" title="13 1"></td><td class="" title="14 1"></td><td class="" title="15 1"></td><td class="" title="16 1"></td><td class="" title="17 1"></td><td class="" title="18 1"></td><td class="" title="19 1"></td><td class="" title="20 1"></td><td class="" title="21 1"></td><td class="" title="22 1"></td><td class="" title="23 1"></td><td class="" title="24 1"></td><td class="" title="25 1"></td><td class="" title="26 1"></td><td class="" title="27 1"></td><td class="" title="28 1"></td><td class="" title="29 1"></td><td class="" title="30 1"></td><td class="" title="31 1"></td><td class="" title="32 1"></td><td class="" title="33 1"></td><td class="" title="34 1"></td><td class="" title="35 1"></td><td class="" title="36 1"></td><td class="" title="37 1"></td><td class="" title="38 1"></td><td class="" title="39 1"></td><td class="" title="40 1"></td><td class="" title="41 1"></td><td class="" title="42 1"></td><td class="" title="43 1"></td></tr>
# <tr><td class="" title="0 2"></td><td class="" title="1 2"></td><td class="" title="2 2"></td><td class="" title="3 2"></td><td class="" title="4 2"></td><td class="" title="5 2"></td><td class="" title="6 2"></td><td class="" title="7 2"></td><td class="" title="8 2"></td><td class="" title="9 2"></td><td class="" title="10 2"></td><td class="" title="11 2"></td><td class="" title="12 2"></td><td class="" title="13 2"></td><td class="" title="14 2"></td><td class="" title="15 2"></td><td class="xb" title="16 2">Highlight significant changes over the last year?</td><td class="" title="17 2"></td><td class="" title="18 2"></td><td class="xb" title="19 2"></td><td class="" title="20 2"></td><td class="" title="21 2"></td><td class="" title="22 2"></td><td class="" title="23 2"></td><td class="" title="24 2"></td><td class="" title="25 2"></td><td class="" title="26 2"></td><td class="xn" title="27 2">1</td><td class="" title="28 2"></td><td class="" title="29 2"></td><td class="" title="30 2"></td><td class="" title="31 2"></td><td class="" title="32 2"></td><td class="" title="33 2"></td><td class="" title="34 2"></td><td class="" title="35 2"></td><td class="" title="36 2"></td><td class="" title="37 2"></td><td class="" title="38 2"></td><td class="" title="39 2"></td><td class="" title="40 2"></td><td class="" title="41 2"></td><td class="" title="42 2"></td><td class="" title="43 2"></td></tr>
# <tr><td class="" title="0 3"></td><td class="" title="1 3"></td><td class="" title="2 3"></td><td class="" title="3 3"></td><td class="" title="4 3"></td><td class="" title="5 3"></td><td class="" title="6 3"></td><td class="" title="7 3"></td><td class="" title="8 3"></td><td class="" title="9 3"></td><td class="" title="10 3"></td><td class="" title="11 3"></td><td class="" title="12 3"></td><td class="" title="13 3"></td><td class="" title="14 3"></td><td class="" title="15 3"></td><td class="" title="16 3"></td><td class="" title="17 3"></td><td class="" title="18 3"></td><td class="" title="19 3"></td><td class="" title="20 3"></td><td class="" title="21 3"></td><td class="" title="22 3"></td><td class="" title="23 3"></td><td class="" title="24 3"></td><td class="" title="25 3"></td><td class="" title="26 3"></td><td class="" title="27 3"></td><td class="" title="28 3"></td><td class="" title="29 3"></td><td class="" title="30 3"></td><td class="" title="31 3"></td><td class="" title="32 3"></td><td class="" title="33 3"></td><td class="" title="34 3"></td><td class="" title="35 3"></td><td class="" title="36 3"></td><td class="" title="37 3"></td><td class="" title="38 3"></td><td class="" title="39 3"></td><td class="" title="40 3"></td><td class="" title="41 3"></td><td class="" title="42 3"></td><td class="" title="43 3"></td></tr>
# <tr><td class="" title="0 4"></td><td class="" title="1 4"></td><td class="" title="2 4"></td><td class="" title="3 4"></td><td class="" title="4 4"></td><td class="" title="5 4"></td><td class="" title="6 4"></td><td class="" title="7 4"></td><td class="" title="8 4"></td><td class="" title="9 4"></td><td class="" title="10 4"></td><td class="" title="11 4"></td><td class="" title="12 4"></td><td class="" title="13 4"></td><td class="" title="14 4"></td><td class="" title="15 4"></td><td class="" title="16 4"></td><td class="" title="17 4"></td><td class="" title="18 4"></td><td class="" title="19 4"></td><td class="" title="20 4"></td><td class="" title="21 4"></td><td class="" title="22 4"></td><td class="" title="23 4"></td><td class="" title="24 4"></td><td class="" title="25 4"></td><td class="" title="26 4"></td><td class="" t

# %%
new_table = c1.topandas()
new_table
# Out:
#       OBS DATAMARKER    Year          Geography         Citizenship1  \
# 0     589        NaN  2004.0     United Kingdom        All countries
# 1      40        NaN  2004.0     United Kingdom        All countries
# 2     151        NaN  2004.0     United Kingdom      European Union2
# 3      24        NaN  2004.0     United Kingdom      European Union2
# 4      98        NaN  2004.0     United Kingdom      European Union2
# 5      18        NaN  2004.0     United Kingdom      European Union2
# 6      51        NaN  2004.0     United Kingdom      European Union2
# 7      16        NaN  2004.0     United Kingdom      European Union2
# 8                  z  2004.0     United Kingdom      European Union2
# 9                  z  2004.0     United Kingdom      European Union2
# 10      2        NaN  2004.0     United Kingdom      European Union2
# 11      2        NaN  2004.0     United Kingdom      European Union2
# 12    438        NaN  2004.0     United Kingdom  Non-European Union3
# 13     32        NaN  2004.0     United Kingdom  Non-European Union3
# 14     19        NaN  2004.0     United Kingdom  Non-European Union3
# 15      6        NaN  2004.0     United Kingdom  Non-European Union3
# 16    213        NaN  2004.0     United Kingdom  Non-European Union3
# 17     25        NaN  2004.0     United Kingdom  Non-European Union3
# 18     31        NaN  2004.0     United Kingdom  Non-European Union3
# 19     12        NaN  2004.0     United Kingdom  Non-European Union3
# 20     57        NaN  2004.0     United Kingdom  Non-European Union3
# 21     16        NaN  2004.0     United Kingdom  Non-European Union3
# 22     91        NaN  2004.0     United Kingdom  Non-European Union3
# 23     14        NaN  2004.0     United Kingdom  Non-European Union3
# 24     33        NaN  2004.0     United Kingdom  Non-European Union3
# 25      8        NaN  2004.0     United Kingdom  Non-European Union3
# 26    206        NaN  2004.0     United Kingdom  Non-European Union3
# 27     18        NaN  2004.0     United Kingdom  Non-European Union3
# 28     96        NaN  2004.0     United Kingdom  Non-European Union3
# 29     13        NaN  2004.0     United Kingdom  Non-European Union3
# ...   ...        ...     ...                ...                  ...
# 3045   50        NaN    2016  England and Wales      European Union2
# 3046   13        NaN    2016  England and Wales      European Union2
# 3047   -1        NaN    2016  England and Wales      European Union2
# 3048    2        NaN    2016  England and Wales      European Union2
# 3049  130        NaN    2016  England and Wales  Non-European Union3
# 3050   25        NaN    2016  England and Wales  Non-European Union3
# 3051   13        NaN    2016  England and Wales  Non-European Union3
# 3052    6        NaN    2016  England and Wales  Non-European Union3
# 3053   97        NaN    2016  England and Wales  Non-European Union3
# 3054   17        NaN    2016  England and Wales  Non-European Union3
# 3055   25        NaN    2016  England and Wales  Non-European Union3
# 3056    7        NaN    2016  England and Wales  Non-European Union3
# 3057   30        NaN    2016  England and Wales  Non-European Union3
# 3058   12        NaN    2016  England and Wales  Non-European Union3
# 3059   36        NaN    2016  England and Wales  Non-European Union3
# 3060    8        NaN    2016  England and Wales  Non-European Union3
# 3061    7        NaN    2016  England and Wales  Non-European Union3
# 3062    6        NaN    2016  England and Wales  Non-European Union3
# 3063   21        NaN    2016  England and Wales  Non-European Union3
# 3064   17        NaN    2016  England and Wales  Non-European Union3
# 3065   21        NaN    2016  England and Wales  Non-European Union3
# 3066    6        NaN    2016  England and Wales  Non-European Union3
# 3067    3        NaN    2016  England and Wales  Non-European Union3
# 3068    4        NaN    2016  England and Wales  Non-European Union3
# 3069   -6        NaN    2016  England and Wales  Non-European Union3
# 3070    9        NaN    2016  England and Wales  Non-European Union3
# 3071    7        NaN    2016  England and Wales  Non-European Union3
# 3072    7        NaN    2016  England and Wales  Non-European Union3
# 3073   -5        NaN    2016  England and Wales  Non-European Union3
# 3074    9        NaN    2016  England and Wales  Non-European Union3
#
#                     Region                     Territory     Flow  \
# 0                     None                          None   Inflow
# 1                     None                          None   Inflow
# 2          European Union2                          None   Inflow
# 3          European Union2                          None   Inflow
# 4      European Union EU15                          None   Inflow
# 5      European Union EU15                          None   Inflow
# 6       European Union EU8                          None   Inflow
# 7       European Union EU8                          None   Inflow
# 8       European Union EU2                          None   Inflow
# 9       European Union EU2                          None   Inflow
# 10    European Union Other                          None   Inflow
# 11    European Union Other                          None   Inflow
# 12                    All3                          None   Inflow
# 13                    All3                          None   Inflow
# 14           Other Europe3                          None   Inflow
# 15           Other Europe3                          None   Inflow
# 16                    Asia                           All   Inflow
# 17                    Asia                           All   Inflow
# 18                    Asia  Middle East and Central Asia   Inflow
# 19                    Asia  Middle East and Central Asia   Inflow
# 20                    Asia                     East Asia   Inflow
# 21                    Asia                     East Asia   Inflow
# 22                    Asia                    South Asia   Inflow
# 23                    Asia                    South Asia   Inflow
# 24                    Asia               South East Asia   Inflow
# 25                    Asia               South East Asia   Inflow
# 26       Rest of the World                           All   Inflow
# 27       Rest of the World                           All   Inflow
# 28       Rest of the World            Sub-Saharan Africa   Inflow
# 29       Rest of the World            Sub-Saharan Africa   Inflow
# ...                    ...                           ...      ...
# 3045    European Union EU2                          None  Balance
# 3046    European Union EU2                          None  Balance
# 3047  European Union Other                          None  Balance
# 3048  European Union Other                          None  Balance
# 3049                  All3                          None  Balance
# 3050                  All3                          None  Balance
# 3051         Other Europe3                          None  Balance
# 3052         Other Europe3                          None  Balance
# 3053                  Asia                           All  Balance
# 3054                  Asia                           All  Balance
# 3055                  Asia  Middle East and Central Asia  Balance
# 3056                  Asia  Middle East and Central Asia  Balance
# 3057                  Asia                     East Asia  Balance
# 3058                  Asia                     East Asia  Balance
# 3059                  Asia                    South Asia  Balance
# 3060                  Asia                    South Asia  Balance
# 3061                  Asia               South East Asia  Balance
# 3062                  Asia               South East Asia  Balance
# 3063     Rest of the World                           All  Balance
# 3064     Rest of the World                           All  Balance
# 3065     Rest of the World            Sub-Saharan Africa  Balance
# 3066     Rest of the World            Sub-Saharan Africa  Balance
# 3067     Rest of the World                  North Africa  Balance
# 3068     Rest of the World                  North Africa  Balance
# 3069     Rest of the World                 North America  Balance
# 3070     Rest of the World                 North America  Balance
# 3071     Rest of the World     Central and South America  Balance
# 3072     Rest of the World     Central and South America  Balance
# 3073     Rest of the World                       Oceania  Balance
# 3074     Rest of the World                       Oceania  Balance
#
#      Measure Type               Unit       Tag
# 0           Count  People(thousands)  Estimate
# 1           Count  People(thousands)     +/-CI
# 2           Count  People(thousands)  Estimate
# 3           Count  People(thousands)     +/-CI
# 4           Count  People(thousands)  Estimate
# 5           Count  People(thousands)     +/-CI
# 6           Count  People(thousands)  Estimate
# 7           Count  People(thousands)     +/-CI
# 8           Count  People(thousands)  Estimate
# 9           Count  People(thousands)     +/-CI
# 10          Count  People(thousands)  Estimate
# 11          Count  People(thousands)     +/-CI
# 12          Count  People(thousands)  Estimate
# 13          Count  People(thousands)     +/-CI
# 14          Count  People(thousands)  Estimate
# 15          Count  People(thousands)     +/-CI
# 16          Count  People(thousands)  Estimate
# 17          Count  People(thousands)     +/-CI
# 18          Count  People(thousands)  Estimate
# 19          Count  People(thousands)     +/-CI
# 20          Count  People(thousands)  Estimate
# 21          Count  People(thousands)     +/-CI
# 22          Count  People(thousands)  Estimate
# 23          Count  People(thousands)     +/-CI
# 24          Count  People(thousands)  Estimate
# 25          Count  People(thousands)     +/-CI
# 26          Count  People(thousands)  Estimate
# 27          Count  People(thousands)     +/-CI
# 28          Count  People(thousands)  Estimate
# 29          Count  People(thousands)     +/-CI
# ...           ...                ...       ...
# 3045        Count  People(thousands)  Estimate
# 3046        Count  People(thousands)     +/-CI
# 3047        Count  People(thousands)  Estimate
# 3048        Count  People(thousands)     +/-CI
# 3049        Count  People(thousands)  Estimate
# 3050        Count  People(thousands)     +/-CI
# 3051        Count  People(thousands)  Estimate
# 3052        Count  People(thousands)     +/-CI
# 3053        Count  People(thousands)  Estimate
# 3054        Count  People(thousands)     +/-CI
# 3055        Count  People(thousands)  Estimate
# 3056        Count  People(thousands)     +/-CI
# 3057        Count  People(thousands)  Estimate
# 3058        Count  People(thousands)     +/-CI
# 3059        Count  People(thousands)  Estimate
# 3060        Count  People(thousands)     +/-CI
# 3061        Count  People(thousands)  Estimate
# 3062        Count  People(thousands)     +/-CI
# 3063        Count  People(thousands)  Estimate
# 3064        Count  People(thousands)     +/-CI
# 3065        Count  People(thousands)  Estimate
# 3066        Count  People(thousands)     +/-CI
# 3067        Count  People(thousands)  Estimate
# 3068        Count  People(thousands)     +/-CI
# 3069        Count  People(thousands)  Estimate
# 3070        Count  People(thousands)     +/-CI
# 3071        Count  People(thousands)  Estimate
# 3072        Count  People(thousands)     +/-CI
# 3073        Count  People(thousands)  Estimate
# 3074        Count  People(thousands)     +/-CI
#
# [3075 rows x 11 columns]

# %%
new_table.shape
# Out:
# (3075, 11)

# %%
new_table.count()
# Out:
# OBS             3075
# DATAMARKER       139
# Year            3075
# Geography       3075
# Citizenship1    3075
# Region          2914
# Territory       1787
# Flow            3075
# Measure Type    3075
# Unit            3075
# Tag             3075
# dtype: int64

# %%
# new_table.to_csv('abcd.csv')

# %%
# new_table['OBS'] = new_table['OBS'].map(lambda cell:cell.str.replace('NaN', 0 ))

# %%
new_table.dtypes
# Out:
# OBS             object
# DATAMARKER      object
# Year            object
# Geography       object
# Citizenship1    object
# Region          object
# Territory       object
# Flow            object
# Measure Type    object
# Unit            object
# Tag             object
# dtype: object

# %%
new_table[new_table['DATAMARKER'] != 'None']
# Out:
#       OBS DATAMARKER    Year          Geography         Citizenship1  \
# 0     589        NaN  2004.0     United Kingdom        All countries
# 1      40        NaN  2004.0     United Kingdom        All countries
# 2     151        NaN  2004.0     United Kingdom      European Union2
# 3      24        NaN  2004.0     United Kingdom      European Union2
# 4      98        NaN  2004.0     United Kingdom      European Union2
# 5      18        NaN  2004.0     United Kingdom      European Union2
# 6      51        NaN  2004.0     United Kingdom      European Union2
# 7      16        NaN  2004.0     United Kingdom      European Union2
# 8                  z  2004.0     United Kingdom      European Union2
# 9                  z  2004.0     United Kingdom      European Union2
# 10      2        NaN  2004.0     United Kingdom      European Union2
# 11      2        NaN  2004.0     United Kingdom      European Union2
# 12    438        NaN  2004.0     United Kingdom  Non-European Union3
# 13     32        NaN  2004.0     United Kingdom  Non-European Union3
# 14     19        NaN  2004.0     United Kingdom  Non-European Union3
# 15      6        NaN  2004.0     United Kingdom  Non-European Union3
# 16    213        NaN  2004.0     United Kingdom  Non-European Union3
# 17     25        NaN  2004.0     United Kingdom  Non-European Union3
# 18     31        NaN  2004.0     United Kingdom  Non-European Union3
# 19     12        NaN  2004.0     United Kingdom  Non-European Union3
# 20     57        NaN  2004.0     United Kingdom  Non-European Union3
# 21     16        NaN  2004.0     United Kingdom  Non-European Union3
# 22     91        NaN  2004.0     United Kingdom  Non-European Union3
# 23     14        NaN  2004.0     United Kingdom  Non-European Union3
# 24     33        NaN  2004.0     United Kingdom  Non-European Union3
# 25      8        NaN  2004.0     United Kingdom  Non-European Union3
# 26    206        NaN  2004.0     United Kingdom  Non-European Union3
# 27     18        NaN  2004.0     United Kingdom  Non-European Union3
# 28     96        NaN  2004.0     United Kingdom  Non-European Union3
# 29     13        NaN  2004.0     United Kingdom  Non-European Union3
# ...   ...        ...     ...                ...                  ...
# 3045   50        NaN    2016  England and Wales      European Union2
# 3046   13        NaN    2016  England and Wales      European Union2
# 3047   -1        NaN    2016  England and Wales      European Union2
# 3048    2        NaN    2016  England and Wales      European Union2
# 3049  130        NaN    2016  England and Wales  Non-European Union3
# 3050   25        NaN    2016  England and Wales  Non-European Union3
# 3051   13        NaN    2016  England and Wales  Non-European Union3
# 3052    6        NaN    2016  England and Wales  Non-European Union3
# 3053   97        NaN    2016  England and Wales  Non-European Union3
# 3054   17        NaN    2016  England and Wales  Non-European Union3
# 3055   25        NaN    2016  England and Wales  Non-European Union3
# 3056    7        NaN    2016  England and Wales  Non-European Union3
# 3057   30        NaN    2016  England and Wales  Non-European Union3
# 3058   12        NaN    2016  England and Wales  Non-European Union3
# 3059   36        NaN    2016  England and Wales  Non-European Union3
# 3060    8        NaN    2016  England and Wales  Non-European Union3
# 3061    7        NaN    2016  England and Wales  Non-European Union3
# 3062    6        NaN    2016  England and Wales  Non-European Union3
# 3063   21        NaN    2016  England and Wales  Non-European Union3
# 3064   17        NaN    2016  England and Wales  Non-European Union3
# 3065   21        NaN    2016  England and Wales  Non-European Union3
# 3066    6        NaN    2016  England and Wales  Non-European Union3
# 3067    3        NaN    2016  England and Wales  Non-European Union3
# 3068    4        NaN    2016  England and Wales  Non-European Union3
# 3069   -6        NaN    2016  England and Wales  Non-European Union3
# 3070    9        NaN    2016  England and Wales  Non-European Union3
# 3071    7        NaN    2016  England and Wales  Non-European Union3
# 3072    7        NaN    2016  England and Wales  Non-European Union3
# 3073   -5        NaN    2016  England and Wales  Non-European Union3
# 3074    9        NaN    2016  England and Wales  Non-European Union3
#
#                     Region                     Territory     Flow  \
# 0                     None                          None   Inflow
# 1                     None                          None   Inflow
# 2          European Union2                          None   Inflow
# 3          European Union2                          None   Inflow
# 4      European Union EU15                          None   Inflow
# 5      European Union EU15                          None   Inflow
# 6       European Union EU8                          None   Inflow
# 7       European Union EU8                          None   Inflow
# 8       European Union EU2                          None   Inflow
# 9       European Union EU2                          None   Inflow
# 10    European Union Other                          None   Inflow
# 11    European Union Other                          None   Inflow
# 12                    All3                          None   Inflow
# 13                    All3                          None   Inflow
# 14           Other Europe3                          None   Inflow
# 15           Other Europe3                          None   Inflow
# 16                    Asia                           All   Inflow
# 17                    Asia                           All   Inflow
# 18                    Asia  Middle East and Central Asia   Inflow
# 19                    Asia  Middle East and Central Asia   Inflow
# 20                    Asia                     East Asia   Inflow
# 21                    Asia                     East Asia   Inflow
# 22                    Asia                    South Asia   Inflow
# 23                    Asia                    South Asia   Inflow
# 24                    Asia               South East Asia   Inflow
# 25                    Asia               South East Asia   Inflow
# 26       Rest of the World                           All   Inflow
# 27       Rest of the World                           All   Inflow
# 28       Rest of the World            Sub-Saharan Africa   Inflow
# 29       Rest of the World            Sub-Saharan Africa   Inflow
# ...                    ...                           ...      ...
# 3045    European Union EU2                          None  Balance
# 3046    European Union EU2                          None  Balance
# 3047  European Union Other                          None  Balance
# 3048  European Union Other                          None  Balance
# 3049                  All3                          None  Balance
# 3050                  All3                          None  Balance
# 3051         Other Europe3                          None  Balance
# 3052         Other Europe3                          None  Balance
# 3053                  Asia                           All  Balance
# 3054                  Asia                           All  Balance
# 3055                  Asia  Middle East and Central Asia  Balance
# 3056                  Asia  Middle East and Central Asia  Balance
# 3057                  Asia                     East Asia  Balance
# 3058                  Asia                     East Asia  Balance
# 3059                  Asia                    South Asia  Balance
# 3060                  Asia                    South Asia  Balance
# 3061                  Asia               South East Asia  Balance
# 3062                  Asia               South East Asia  Balance
# 3063     Rest of the World                           All  Balance
# 3064     Rest of the World                           All  Balance
# 3065     Rest of the World            Sub-Saharan Africa  Balance
# 3066     Rest of the World            Sub-Saharan Africa  Balance
# 3067     Rest of the World                  North Africa  Balance
# 3068     Rest of the World                  North Africa  Balance
# 3069     Rest of the World                 North America  Balance
# 3070     Rest of the World                 North America  Balance
# 3071     Rest of the World     Central and South America  Balance
# 3072     Rest of the World     Central and South America  Balance
# 3073     Rest of the World                       Oceania  Balance
# 3074     Rest of the World                       Oceania  Balance
#
#      Measure Type               Unit       Tag
# 0           Count  People(thousands)  Estimate
# 1           Count  People(thousands)     +/-CI
# 2           Count  People(thousands)  Estimate
# 3           Count  People(thousands)     +/-CI
# 4           Count  People(thousands)  Estimate
# 5           Count  People(thousands)     +/-CI
# 6           Count  People(thousands)  Estimate
# 7           Count  People(thousands)     +/-CI
# 8           Count  People(thousands)  Estimate
# 9           Count  People(thousands)     +/-CI
# 10          Count  People(thousands)  Estimate
# 11          Count  People(thousands)     +/-CI
# 12          Count  People(thousands)  Estimate
# 13          Count  People(thousands)     +/-CI
# 14          Count  People(thousands)  Estimate
# 15          Count  People(thousands)     +/-CI
# 16          Count  People(thousands)  Estimate
# 17          Count  People(thousands)     +/-CI
# 18          Count  People(thousands)  Estimate
# 19          Count  People(thousands)     +/-CI
# 20          Count  People(thousands)  Estimate
# 21          Count  People(thousands)     +/-CI
# 22          Count  People(thousands)  Estimate
# 23          Count  People(thousands)     +/-CI
# 24          Count  People(thousands)  Estimate
# 25          Count  People(thousands)     +/-CI
# 26          Count  People(thousands)  Estimate
# 27          Count  People(thousands)     +/-CI
# 28          Count  People(thousands)  Estimate
# 29          Count  People(thousands)     +/-CI
# ...           ...                ...       ...
# 3045        Count  People(thousands)  Estimate
# 3046        Count  People(thousands)     +/-CI
# 3047        Count  People(thousands)  Estimate
# 3048        Count  People(thousands)     +/-CI
# 3049        Count  People(thousands)  Estimate
# 3050        Count  People(thousands)     +/-CI
# 3051        Count  People(thousands)  Estimate
# 3052        Count  People(thousands)     +/-CI
# 3053        Count  People(thousands)  Estimate
# 3054        Count  People(thousands)     +/-CI
# 3055        Count  People(thousands)  Estimate
# 3056        Count  People(thousands)     +/-CI
# 3057        Count  People(thousands)  Estimate
# 3058        Count  People(thousands)     +/-CI
# 3059        Count  People(thousands)  Estimate
# 3060        Count  People(thousands)     +/-CI
# 3061        Count  People(thousands)  Estimate
# 3062        Count  People(thousands)     +/-CI
# 3063        Count  People(thousands)  Estimate
# 3064        Count  People(thousands)     +/-CI
# 3065        Count  People(thousands)  Estimate
# 3066        Count  People(thousands)     +/-CI
# 3067        Count  People(thousands)  Estimate
# 3068        Count  People(thousands)     +/-CI
# 3069        Count  People(thousands)  Estimate
# 3070        Count  People(thousands)     +/-CI
# 3071        Count  People(thousands)  Estimate
# 3072        Count  People(thousands)     +/-CI
# 3073        Count  People(thousands)  Estimate
# 3074        Count  People(thousands)     +/-CI
#
# [3075 rows x 11 columns]

# %%
new_table.OBS.fillna('0', inplace = True)

# %%
new_table.fillna('None', inplace = True)

# %%
def user_perc(x,y):
    
    if str(x) == 'None':
        return y
    else:
        return 0
    
new_table['OBS'] = new_table.apply(lambda row: user_perc(row['DATAMARKER'], row['OBS']), axis = 1)

# %%
new_table.count()
# Out:
# OBS             3075
# DATAMARKER      3075
# Year            3075
# Geography       3075
# Citizenship1    3075
# Region          3075
# Territory       3075
# Flow            3075
# Measure Type    3075
# Unit            3075
# Tag             3075
# dtype: int64

# %%
# new_table = new_table[new_table['OBS'] != '']

# %%
# new_table = new_table[new_table['OBS'] != 0 ]

# %%
# new_table[new_table['OBS'] == '0~']

# %%
# new_table['OBS'] = new_table['OBS'].str.rstrip(':~')

# %%
# new_table.to_csv('abc.csv')

# %%
new_table['Citizenship1'] = new_table['Citizenship1'].str.rstrip('23')

# %%
new_table['Region'] = new_table['Region'].str.rstrip('3')

# %%
# new_table['Region'] = new_table['Region'].map(lambda cell:cell.replace('Europe3', 'Europe'))

# %%
new_table['Region'] = new_table['Region'].map(lambda cell:cell.replace('Union2', 'Union'))

# %%
new_table['Territory'] = new_table['Territory'].str.rstrip('1')

# %%
new_table['Key'] = new_table['Year'] + '/' + new_table['Geography'] + '/' + new_table['Citizenship1'] + '/' + new_table['Region'] + '/' + new_table['Territory'] + '/' + new_table['Flow']

# %%
# new_table['Row'] = new_table.index

# %%
# temp_table = pd.merge(new_table, Final_table[['Key', 'OBS_x','Tag_x','Row_x']], how = 'left', left_on = 'Row', right_on = 'Row_x')

# %%
# temp_table.count()

# %%
# temp_table[temp_table.Row_x.isnull()== True]

# %%
Final_table = pd.merge(new_table, new_table[['Key','OBS','Tag']], how = 'left', left_on = 'Key', right_on = 'Key')

# %%
new_table.count()
# Out:
# OBS             3075
# DATAMARKER      3075
# Year            3075
# Geography       3075
# Citizenship1    3075
# Region          3075
# Territory       3075
# Flow            3075
# Measure Type    3075
# Unit            3075
# Tag             3075
# Key             3075
# dtype: int64

# %%
Final_table.count()
# Out:
# OBS_x           6055
# DATAMARKER      6055
# Year            6055
# Geography       6055
# Citizenship1    6055
# Region          6055
# Territory       6055
# Flow            6055
# Measure Type    6055
# Unit            6055
# Tag_x           6055
# Key             6055
# OBS_y           6055
# Tag_y           6055
# dtype: int64

# %%
Final_table  = Final_table[Final_table['Tag_x'] != Final_table['Tag_y']]

# %%
Final_table.count()
# Out:
# OBS_x           2980
# DATAMARKER      2980
# Year            2980
# Geography       2980
# Citizenship1    2980
# Region          2980
# Territory       2980
# Flow            2980
# Measure Type    2980
# Unit            2980
# Tag_x           2980
# Key             2980
# OBS_y           2980
# Tag_y           2980
# dtype: int64

# %%
Final_table.drop_duplicates('Key', inplace = True)

# %%
Final_table.count()
# Out:
# OBS_x           1490
# DATAMARKER      1490
# Year            1490
# Geography       1490
# Citizenship1    1490
# Region          1490
# Territory       1490
# Flow            1490
# Measure Type    1490
# Unit            1490
# Tag_x           1490
# Key             1490
# OBS_y           1490
# Tag_y           1490
# dtype: int64

# %%
Final_table['OBS_x'] = Final_table['OBS_x'].astype(int)

# %%
Final_table['OBS_y'] = pd.to_numeric(Final_table['OBS_y'])

# %%
Final_table['OBS_y'].fillna(0, inplace = True)

# %%
Final_table['OBS_y'] = Final_table['OBS_y'].astype(int)

# %%
# Final_table['Value'] = Final_table['OBS_x'].astype(str) + ' ± '+ Final_table['OBS_y'].astype(str)

# %%
Final_table['Value'] = Final_table['OBS_x'].astype(str)

# %%
Final_table['CI'] = Final_table['OBS_y'].astype(str)

# %%
Final_table
# Out:
#       OBS_x DATAMARKER    Year          Geography        Citizenship1  \
# 1       589       None  2004.0     United Kingdom       All countries
# 5       151       None  2004.0     United Kingdom      European Union
# 9        98       None  2004.0     United Kingdom      European Union
# 13       51       None  2004.0     United Kingdom      European Union
# 17        0          z  2004.0     United Kingdom      European Union
# 21        2       None  2004.0     United Kingdom      European Union
# 25      438       None  2004.0     United Kingdom  Non-European Union
# 29       19       None  2004.0     United Kingdom  Non-European Union
# 33      213       None  2004.0     United Kingdom  Non-European Union
# 37       31       None  2004.0     United Kingdom  Non-European Union
# 41       57       None  2004.0     United Kingdom  Non-European Union
# 45       91       None  2004.0     United Kingdom  Non-European Union
# 49       33       None  2004.0     United Kingdom  Non-European Union
# 53      206       None  2004.0     United Kingdom  Non-European Union
# 57       96       None  2004.0     United Kingdom  Non-European Union
# 61        7       None  2004.0     United Kingdom  Non-European Union
# 65       34       None  2004.0     United Kingdom  Non-European Union
# 69       15       None  2004.0     United Kingdom  Non-European Union
# 73       53       None  2004.0     United Kingdom  Non-European Union
# 77      567       None  2005.0     United Kingdom       All countries
# 81      185       None  2005.0     United Kingdom      European Union
# 85      105       None  2005.0     United Kingdom      European Union
# 89       77       None  2005.0     United Kingdom      European Union
# 93        0          z  2005.0     United Kingdom      European Union
# 97        3       None  2005.0     United Kingdom      European Union
# 101     381       None  2005.0     United Kingdom  Non-European Union
# 105      22       None  2005.0     United Kingdom  Non-European Union
# 109     188       None  2005.0     United Kingdom  Non-European Union
# 113      22       None  2005.0     United Kingdom  Non-European Union
# 117      49       None  2005.0     United Kingdom  Non-European Union
# ...     ...        ...     ...                ...                 ...
# 5936    106       None    2015  England and Wales  Non-European Union
# 5940     26       None    2015  England and Wales  Non-European Union
# 5944     40       None    2015  England and Wales  Non-European Union
# 5948     32       None    2015  England and Wales  Non-European Union
# 5952      9       None    2015  England and Wales  Non-European Union
# 5956     36       None    2015  England and Wales  Non-European Union
# 5960     23       None    2015  England and Wales  Non-European Union
# 5964      5       None    2015  England and Wales  Non-European Union
# 5968      3       None    2015  England and Wales  Non-European Union
# 5972      6       None    2015  England and Wales  Non-European Union
# 5976      0       None    2015  England and Wales  Non-European Union
# 5980    231       None    2016  England and Wales       All countries
# 5984    101       None    2016  England and Wales      European Union
# 5988     52       None    2016  England and Wales      European Union
# 5992      0       None    2016  England and Wales      European Union
# 5996     50       None    2016  England and Wales      European Union
# 6000     -1       None    2016  England and Wales      European Union
# 6004    130       None    2016  England and Wales  Non-European Union
# 6008     13       None    2016  England and Wales  Non-European Union
# 6012     97       None    2016  England and Wales  Non-European Union
# 6016     25       None    2016  England and Wales  Non-European Union
# 6020     30       None    2016  England and Wales  Non-European Union
# 6024     36       None    2016  England and Wales  Non-European Union
# 6028      7       None    2016  England and Wales  Non-European Union
# 6032     21       None    2016  England and Wales  Non-European Union
# 6036     21       None    2016  England and Wales  Non-European Union
# 6040      3       None    2016  England and Wales  Non-European Union
# 6044     -6       None    2016  England and Wales  Non-European Union
# 6048      7       None    2016  England and Wales  Non-European Union
# 6052     -5       None    2016  England and Wales  Non-European Union
#
#                     Region                     Territory     Flow  \
# 1                     None                          None   Inflow
# 5           European Union                          None   Inflow
# 9      European Union EU15                          None   Inflow
# 13      European Union EU8                          None   Inflow
# 17      European Union EU2                          None   Inflow
# 21    European Union Other                          None   Inflow
# 25                     All                          None   Inflow
# 29            Other Europe                          None   Inflow
# 33                    Asia                           All   Inflow
# 37                    Asia  Middle East and Central Asia   Inflow
# 41                    Asia                     East Asia   Inflow
# 45                    Asia                    South Asia   Inflow
# 49                    Asia               South East Asia   Inflow
# 53       Rest of the World                           All   Inflow
# 57       Rest of the World            Sub-Saharan Africa   Inflow
# 61       Rest of the World                  North Africa   Inflow
# 65       Rest of the World                 North America   Inflow
# 69       Rest of the World     Central and South America   Inflow
# 73       Rest of the World                       Oceania   Inflow
# 77                    None                          None   Inflow
# 81          European Union                          None   Inflow
# 85     European Union EU15                          None   Inflow
# 89      European Union EU8                          None   Inflow
# 93      European Union EU2                          None   Inflow
# 97    European Union Other                          None   Inflow
# 101                    All                          None   Inflow
# 105           Other Europe                          None   Inflow
# 109                   Asia                           All   Inflow
# 113                   Asia  Middle East and Central Asia   Inflow
# 117                   Asia                     East Asia   Inflow
# ...                    ...                           ...      ...
# 5936                  Asia                           All  Balance
# 5940                  Asia  Middle East and Central Asia  Balance
# 5944                  Asia                     East Asia  Balance
# 5948                  Asia                    South Asia  Balance
# 5952                  Asia               South East Asia  Balance
# 5956     Rest of the World                           All  Balance
# 5960     Rest of the World            Sub-Saharan Africa  Balance
# 5964     Rest of the World                  North Africa  Balance
# 5968     Rest of the World                 North America  Balance
# 5972     Rest of the World     Central and South America  Balance
# 5976     Rest of the World                       Oceania  Balance
# 5980                  None                          None  Balance
# 5984        European Union                          None  Balance
# 5988   European Union EU15                          None  Balance
# 5992    European Union EU8                          None  Balance
# 5996    European Union EU2                          None  Balance
# 6000  European Union Other                          None  Balance
# 6004                   All                          None  Balance
# 6008          Other Europe                          None  Balance
# 6012                  Asia                           All  Balance
# 6016                  Asia  Middle East and Central Asia  Balance
# 6020                  Asia                     East Asia  Balance
# 6024                  Asia                    South Asia  Balance
# 6028                  Asia               South East Asia  Balance
# 6032     Rest of the World                           All  Balance
# 6036     Rest of the World            Sub-Saharan Africa  Balance
# 6040     Rest of the World                  North Africa  Balance
# 6044     Rest of the World                 North America  Balance
# 6048     Rest of the World     Central and South America  Balance
# 6052     Rest of the World                       Oceania  Balance
#
#      Measure Type               Unit     Tag_x  \
# 1           Count  People(thousands)  Estimate
# 5           Count  People(thousands)  Estimate
# 9           Count  People(thousands)  Estimate
# 13          Count  People(thousands)  Estimate
# 17          Count  People(thousands)  Estimate
# 21          Count  People(thousands)  Estimate
# 25          Count  People(thousands)  Estimate
# 29          Count  People(thousands)  Estimate
# 33          Count  People(thousands)  Estimate
# 37          Count  People(thousands)  Estimate
# 41          Count  People(thousands)  Estimate
# 45          Count  People(thousands)  Estimate
# 49          Count  People(thousands)  Estimate
# 53          Count  People(thousands)  Estimate
# 57          Count  People(thousands)  Estimate
# 61          Count  People(thousands)  Estimate
# 65          Count  People(thousands)  Estimate
# 69          Count  People(thousands)  Estimate
# 73          Count  People(thousands)  Estimate
# 77          Count  People(thousands)  Estimate
# 81          Count  People(thousands)  Estimate
# 85          Count  People(thousands)  Estimate
# 89          Count  People(thousands)  Estimate
# 93          Count  People(thousands)  Estimate
# 97          Count  People(thousands)  Estimate
# 101         Count  People(thousands)  Estimate
# 105         Count  People(thousands)  Estimate
# 109         Count  People(thousands)  Estimate
# 113         Count  People(thousands)  Estimate
# 117         Count  People(thousands)  Estimate
# ...           ...                ...       ...
# 5936        Count  People(thousands)  Estimate
# 5940        Count  People(thousands)  Estimate
# 5944        Count  People(thousands)  Estimate
# 5948        Count  People(thousands)  Estimate
# 5952        Count  People(thousands)  Estimate
# 5956        Count  People(thousands)  Estimate
# 5960        Count  People(thousands)  Estimate
# 5964        Count  People(thousands)  Estimate
# 5968        Count  People(thousands)  Estimate
# 5972        Count  People(thousands)  Estimate
# 5976        Count  People(thousands)  Estimate
# 5980        Count  People(thousands)  Estimate
# 5984        Count  People(thousands)  Estimate
# 5988        Count  People(thousands)  Estimate
# 5992        Count  People(thousands)  Estimate
# 5996        Count  People(thousands)  Estimate
# 6000        Count  People(thousands)  Estimate
# 6004        Count  People(thousands)  Estimate
# 6008        Count  People(thousands)  Estimate
# 6012        Count  People(thousands)  Estimate
# 6016        Count  People(thousands)  Estimate
# 6020        Count  People(thousands)  Estimate
# 6024        Count  People(thousands)  Estimate
# 6028        Count  People(thousands)  Estimate
# 6032        Count  People(thousands)  Estimate
# 6036        Count  People(thousands)  Estimate
# 6040        Count  People(thousands)  Estimate
# 6044        Count  People(thousands)  Estimate
# 6048        Count  People(thousands)  Estimate
# 6052        Count  People(thousands)  Estimate
#
#                                                     Key  OBS_y  Tag_y Value  \
# 1     2004.0/United Kingdom/All countries/None/None/...     40  +/-CI   589
# 5     2004.0/United Kingdom/European Union/European ...     24  +/-CI   151
# 9     2004.0/United Kingdom/European Union/European ...     18  +/-CI    98
# 13    2004.0/United Kingdom/European Union/European ...     16  +/-CI    51
# 17    2004.0/United Kingdom/European Union/European ...      0  +/-CI     0
# 21    2004.0/United Kingdom/European Union/European ...      2  +/-CI     2
# 25    2004.0/United Kingdom/Non-European Union/All/N...     32  +/-CI   438
# 29    2004.0/United Kingdom/Non-European Union/Other...      6  +/-CI    19
# 33    2004.0/United Kingdom/Non-European Union/Asia/...     25  +/-CI   213
# 37    2004.0/United Kingdom/Non-European Union/Asia/...     12  +/-CI    31
# 41    2004.0/United Kingdom/Non-European Union/Asia/...     16  +/-CI    57
# 45    2004.0/United Kingdom/Non-European Union/Asia/...     14  +/-CI    91
# 49    2004.0/United Kingdom/Non-European Union/Asia/...      8  +/-CI    33
# 53    2004.0/United Kingdom/Non-European Union/Rest ...     18  +/-CI   206
# 57    2004.0/United Kingdom/Non-European Union/Rest ...     13  +/-CI    96
# 61    2004.0/United Kingdom/Non-European Union/Rest ...      3  +/-CI     7
# 65    2004.0/United Kingdom/Non-European Union/Rest ...      8  +/-CI    34
# 69    2004.0/United Kingdom/Non-European Union/Rest ...      6  +/-CI    15
# 73    2004.0/United Kingdom/Non-European Union/Rest ...      8  +/-CI    53
# 77    2005.0/United Kingdom/All countries/None/None/...     37  +/-CI   567
# 81    2005.0/United Kingdom/European Union/European ...     27  +/-CI   185
# 85    2005.0/United Kingdom/European Union/European ...     19  +/-CI   105
# 89    2005.0/United Kingdom/European Union/European ...     18  +/-CI    77
# 93    2005.0/United Kingdom/European Union/European ...      0  +/-CI     0
# 97    2005.0/United Kingdom/European Union/European ...      3  +/-CI     3
# 101   2005.0/United Kingdom/Non-European Union/All/N...     26  +/-CI   381
# 105   2005.0/United Kingdom/Non-European Union/Other...      8  +/-CI    22
# 109   2005.0/United Kingdom/Non-European Union/Asia/...     20  +/-CI   188
# 113   2005.0/United Kingdom/Non-European Union/Asia/...      5  +/-CI    22
# 117   2005.0/United Kingdom/Non-European Union/Asia/...     12  +/-CI    49
# ...                                                 ...    ...    ...   ...
# 5936  2015/England and Wales/Non-European Union/Asia...     16  +/-CI   106
# 5940  2015/England and Wales/Non-European Union/Asia...      7  +/-CI    26
# 5944  2015/England and Wales/Non-European Union/Asia...     11  +/-CI    40
# 5948  2015/England and Wales/Non-European Union/Asia...      7  +/-CI    32
# 5952  2015/England and Wales/Non-European Union/Asia...      7  +/-CI     9
# 5956  2015/England and Wales/Non-European Union/Rest...     15  +/-CI    36
# 5960  2015/England and Wales/Non-European Union/Rest...      6  +/-CI    23
# 5964  2015/England and Wales/Non-European Union/Rest...      2  +/-CI     5
# 5968  2015/England and Wales/Non-European Union/Rest...      8  +/-CI     3
# 5972  2015/England and Wales/Non-European Union/Rest...      6  +/-CI     6
# 5976  2015/England and Wales/Non-European Union/Rest...      9  +/-CI     0
# 5980  2016/England and Wales/All countries/None/None...     39  +/-CI   231
# 5984  2016/England and Wales/European Union/European...     31  +/-CI   101
# 5988  2016/England and Wales/European Union/European...     24  +/-CI    52
# 5992  2016/England and Wales/European Union/European...     13  +/-CI     0
# 5996  2016/England and Wales/European Union/European...     13  +/-CI    50
# 6000  2016/England and Wales/European Union/European...      2  +/-CI    -1
# 6004  2016/England and Wales/Non-European Union/All/...     25  +/-CI   130
# 6008  2016/England and Wales/Non-European Union/Othe...      6  +/-CI    13
# 6012  2016/England and Wales/Non-European Union/Asia...     17  +/-CI    97
# 6016  2016/England and Wales/Non-European Union/Asia...      7  +/-CI    25
# 6020  2016/England and Wales/Non-European Union/Asia...     12  +/-CI    30
# 6024  2016/England and Wales/Non-European Union/Asia...      8  +/-CI    36
# 6028  2016/England and Wales/Non-European Union/Asia...      6  +/-CI     7
# 6032  2016/England and Wales/Non-European Union/Rest...     17  +/-CI    21
# 6036  2016/England and Wales/Non-European Union/Rest...      6  +/-CI    21
# 6040  2016/England and Wales/Non-European Union/Rest...      4  +/-CI     3
# 6044  2016/England and Wales/Non-European Union/Rest...      9  +/-CI    -6
# 6048  2016/England and Wales/Non-European Union/Rest...      7  +/-CI     7
# 6052  2016/England and Wales/Non-European Union/Rest...      9  +/-CI    -5
#
#       CI
# 1     40
# 5     24
# 9     18
# 13    16
# 17     0
# 21     2
# 25    32
# 29     6
# 33    25
# 37    12
# 41    16
# 45    14
# 49     8
# 53    18
# 57    13
# 61     3
# 65     8
# 69     6
# 73     8
# 77    37
# 81    27
# 85    19
# 89    18
# 93     0
# 97     3
# 101   26
# 105    8
# 109   20
# 113    5
# 117   12
# ...   ..
# 5936  16
# 5940   7
# 5944  11
# 5948   7
# 5952   7
# 5956  15
# 5960   6
# 5964   2
# 5968   8
# 5972   6
# 5976   9
# 5980  39
# 5984  31
# 5988  24
# 5992  13
# 5996  13
# 6000   2
# 6004  25
# 6008   6
# 6012  17
# 6016   7
# 6020  12
# 6024   8
# 6028   6
# 6032  17
# 6036   6
# 6040   4
# 6044   9
# 6048   7
# 6052   9
#
# [1490 rows x 16 columns]

# %%
Final_table['Next or last Residence'] = Final_table['Citizenship1'] + ':' + Final_table['Region'] + ':' + Final_table['Territory']

# %%
Final_table['Next or last Residence'] = Final_table['Next or last Residence'].map(lambda cell:cell.replace(':None', ''))

# %%
# Final_table['Next or last Residence'] = Final_table['Next or last Residence'].str.rstrip(':None')

# %%
Final_table['Year'] = Final_table['Year'].astype(str)

# %%
Final_table['Year'] = pd.to_numeric(Final_table['Year'])

# %%
Final_table['Year'] = Final_table['Year'].astype(int)

# %%
Final_table.dtypes
# Out:
# OBS_x                      int32
# DATAMARKER                object
# Year                       int32
# Geography                 object
# Citizenship1              object
# Region                    object
# Territory                 object
# Flow                      object
# Measure Type              object
# Unit                      object
# Tag_x                     object
# Key                       object
# OBS_y                      int32
# Tag_y                     object
# Value                     object
# CI                        object
# Next or last Residence    object
# dtype: object

# %%
Final_table.tail(5)
# Out:
#       OBS_x DATAMARKER  Year          Geography        Citizenship1  \
# 6036     21       None  2016  England and Wales  Non-European Union
# 6040      3       None  2016  England and Wales  Non-European Union
# 6044     -6       None  2016  England and Wales  Non-European Union
# 6048      7       None  2016  England and Wales  Non-European Union
# 6052     -5       None  2016  England and Wales  Non-European Union
#
#                  Region                  Territory     Flow Measure Type  \
# 6036  Rest of the World         Sub-Saharan Africa  Balance        Count
# 6040  Rest of the World               North Africa  Balance        Count
# 6044  Rest of the World              North America  Balance        Count
# 6048  Rest of the World  Central and South America  Balance        Count
# 6052  Rest of the World                    Oceania  Balance        Count
#
#                    Unit     Tag_x  \
# 6036  People(thousands)  Estimate
# 6040  People(thousands)  Estimate
# 6044  People(thousands)  Estimate
# 6048  People(thousands)  Estimate
# 6052  People(thousands)  Estimate
#
#                                                     Key  OBS_y  Tag_y Value  \
# 6036  2016/England and Wales/Non-European Union/Rest...      6  +/-CI    21
# 6040  2016/England and Wales/Non-European Union/Rest...      4  +/-CI     3
# 6044  2016/England and Wales/Non-European Union/Rest...      9  +/-CI    -6
# 6048  2016/England and Wales/Non-European Union/Rest...      7  +/-CI     7
# 6052  2016/England and Wales/Non-European Union/Rest...      9  +/-CI    -5
#
#      CI                             Next or last Residence
# 6036  6  Non-European Union:Rest of the World:Sub-Sahar...
# 6040  4  Non-European Union:Rest of the World:North Africa
# 6044  9  Non-European Union:Rest of the World:North Ame...
# 6048  7  Non-European Union:Rest of the World:Central a...
# 6052  9       Non-European Union:Rest of the World:Oceania

# %%
Final_table['Geography'] = Final_table['Geography'].map(lambda cell:cell.replace('United Kingdom', 'K02000001'))

# %%
Final_table['Geography'] = Final_table['Geography'].map(lambda cell:cell.replace('England and Wales', 'K04000001'))

# %%
Final_table = Final_table[['Geography','Year','Next or last Residence','Flow','Measure Type','Value','CI','Unit']]

# %%
Final_table.head(5)
# Out:
#     Geography  Year              Next or last Residence    Flow Measure Type  \
# 1   K02000001  2004                       All countries  Inflow        Count
# 5   K02000001  2004       European Union:European Union  Inflow        Count
# 9   K02000001  2004  European Union:European Union EU15  Inflow        Count
# 13  K02000001  2004   European Union:European Union EU8  Inflow        Count
# 17  K02000001  2004   European Union:European Union EU2  Inflow        Count
#
#    Value  CI               Unit
# 1    589  40  People(thousands)
# 5    151  24  People(thousands)
# 9     98  18  People(thousands)
# 13    51  16  People(thousands)
# 17     0   0  People(thousands)

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('tidydata2_2.csv'), index = False)

# %%
writeMetadata(metadata, 'ONS-LTIM-Reason-for-Migration')
